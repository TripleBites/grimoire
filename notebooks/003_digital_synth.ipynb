# %% [markdown]
# # 003 digital synth
# Referances:
# 1. Wavetable synthesis theory (https://thewolfsound.com/sound-synthesis/wavetable-synth-in-python/)
#
# 2. The Synthesizers Playground (https://jupylet.readthedocs.io/en/latest/programmers_reference_guide/synthesis.html)

# %%
# Setup
import logging
# Jupylet's audio backend can log a lot of ALSA warnings; this suppresses them
logging.getLogger().setLevel(logging.ERROR) 

# This single bundle imports everything needed for the synthesis tutorial:
# Synthesizer, Triangle2, Pulse2, LowPassFilter, note constants (C4), and effects.
from jupylet.audio.bundle import *

# Test the audio engine with a built-in synth to confirm your WSL audio is working
tb303.play(C4, 1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       4 logging.getLogger().setLevel(logging.ERROR)
#       5
#       6 # This single bundle imports everything needed for the synthesis tutorial:
#       7 # Synthesizer, Triangle2, Pulse2, LowPassFilter, note constants (C4), and effects.
# ----> 8 from jupylet.audio.bundle import *
#       9
#      10 # Test the audio engine with a built-in synth to confirm your WSL audio is working
#      11 tb303.play(C4, 1)
#
# ModuleNotFoundError: No module named 'jupylet'

# %%
# Sawtooth oscillator
