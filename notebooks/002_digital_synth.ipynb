# %% [markdown]
# # 002 digital synth
# Referances:
# 1. Wavetable synthesis theory (https://thewolfsound.com/sound-synthesis/wavetable-synth-in-python/)
#
# 2. The Synthesizers Playground (https://jupylet.readthedocs.io/en/latest/programmers_reference_guide/synthesis.html)
